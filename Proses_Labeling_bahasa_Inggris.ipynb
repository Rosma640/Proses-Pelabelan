# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosma640/Proses-Pelabelan/blob/main/Proses_Labeling_bahasa_Inggris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
content = pd.read_csv('/content/drive/MyDrive/Skripsi/Ulasan Spotify En.csv')
content.head()
# Out:
#                                               ulasan  label
# 0  Starting in December, the app started crashing...      2
# 1  I've loved this app for many years. Lately, ho...      3
# 2  Spotify is my favorite music streaming app by ...      3
# 3  It's really annoying when the music doesn't ha...      2
# 4  Great library, generally easy to use. Negative...      2

# %%
content = content.rename(columns={'ulasan': 'content', 'label': 'score'}) #mengganti nama fitur
content.head(10)
# Out:
#                                              content  score
# 0  Starting in December, the app started crashing...      2
# 1  I've loved this app for many years. Lately, ho...      3
# 2  Spotify is my favorite music streaming app by ...      3
# 3  It's really annoying when the music doesn't ha...      2
# 4  Great library, generally easy to use. Negative...      2
# 5  I like the app overall and the choice of music...      2
# 6  Please bring back the Enhance feature! Using E...      1
# 7  I used to love this app but the smart shuffle ...      1
# 8  After many years of happily using the Spotify ...      1
# 9  Literally the only thing I want to do is shuff...      1

# %%
content.to_csv("Ulasan Spotify En.csv")

# %%
# @title score

from matplotlib import pyplot as plt
content['score'].plot(kind='hist', bins=20, title='score')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
print(f"Jumlah data {len(content)}")
print(f"score 1 = {len(content[content['score']==1])}")
print(f"score 2 = {len(content[content['score']==2])}")
print(f"score 3 = {len(content[content['score']==3])}")
print(f"score 4 = {len(content[content['score']==4])}")
print(f"score 5 = {len(content[content['score']==5])}")
# Out:
# Jumlah data 1000
# score 1 = 477
# score 2 = 236
# score 3 = 178
# score 4 = 98
# score 5 = 11

# %%
import seaborn as sns
sns.countplot(x='score', data=content);

# %% [markdown]
# # **Pelabelan Data**

# %%
# Pelabelan data ulasan
def pelabelan(score):
  if score < 4:
    return 'Negatif'
  elif score > 3 :
    return 'Positif'
content['Label'] = content ['score'].apply(pelabelan)
content.head(10)
# Out:
#                                              content  score    Label
# 0  Starting in December, the app started crashing...      2  Negatif
# 1  I've loved this app for many years. Lately, ho...      3  Negatif
# 2  Spotify is my favorite music streaming app by ...      3  Negatif
# 3  It's really annoying when the music doesn't ha...      2  Negatif
# 4  Great library, generally easy to use. Negative...      2  Negatif
# 5  I like the app overall and the choice of music...      2  Negatif
# 6  Please bring back the Enhance feature! Using E...      1  Negatif
# 7  I used to love this app but the smart shuffle ...      1  Negatif
# 8  After many years of happily using the Spotify ...      1  Negatif
# 9  Literally the only thing I want to do is shuff...      1  Negatif

# %%
import matplotlib.pyplot as plt

# %%
# @title Label

from matplotlib import pyplot as plt
import seaborn as sns
content.groupby('Label').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
labels = ['Negatif', 'Positif']
sizes = [891, 109]
colors = ['coral', 'lightskyblue']

# %%
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=100)
# Out:
# ([<matplotlib.patches.Wedge at 0x7d4d84590790>,
# ...
#  [Text(-0.18382429810911283, -1.0845315244033675, 'Negatif'),
#   Text(0.18382439965028166, 1.08453150719249, 'Positif')],
#  [Text(-0.10026779896860698, -0.5915626496745641, '89.1%'),
#   Text(0.10026785435469908, 0.5915626402868126, '10.9%')])

# %%
content.to_csv("Hasil Labeling (Inggris).csv")
